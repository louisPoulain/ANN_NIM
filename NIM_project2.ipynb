# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from nim_env import NimEnv, OptimalPlayer
import helpers as h

import torch
import WarningFunctions as wf


# set up matplotlib
is_ipython = 'inline' in matplotlib.get_backend()
if is_ipython:
    from IPython import display

plt.ion()

# if gpu is to be used
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


#parameters
GAMMA = 0.99
buffer_size = 10000
BATCH_SIZE = 64
TARGET_UPDATE = 500


#-------------------------------- helpers DQN ----------------------------

# %%
policy_net = h.DQN().to(device)
target_net = h.DQN().to(device)
target_net.load_state_dict(policy_net.state_dict())
target_net.eval()
memory = h.ReplayMemory(buffer_size)
h.Q11(policy_net, target_net, memory)

# %%
policy_net = h.DQN().to(device)
target_net = h.DQN().to(device)
target_net.load_state_dict(policy_net.state_dict())
target_net.eval()
memory = h.Memory_Q12()
h.Q12(policy_net, target_net, memory)

# %%
N_star = [1, 1000, 5000, 10000, 20000]
h.Q13(N_star)
# Out:
# ({'1': -0.7126399993896484,
#   '1000': -0.7084799766540527,
#   '5000': -0.6804800510406495,
#   '10000': -0.681440019607544,
#   '20000': -0.648960018157959},
#  {'1': 0.8846400260925293,
#   '1000': 0.884320068359375,
#   '5000': 0.9072000503540039,
#   '10000': 0.9294400215148926,
#   '20000': 0.9315199851989746})

# %%
Eps_opt = [0., 0.2, 0.4, 0.6, 0.8, 1]
h.Q14(Eps_opt)

# %%
Eps = [0.0, 0.1, 0.2, 0.4, 0.6, 0.8]
h.Q16(Eps)
# Out:
# eps :  0.0
# eps :  0.1
# eps :  0.2
# eps :  0.4
# eps :  0.6
# eps :  0.8
# ({'0.0': -0.9889599800109863,
#   '0.1': -0.48336000442504884,
#   '0.2': -0.37216002941131593,
#   '0.4': -0.5660799980163574,
#   '0.6': -0.7971199989318848,
#   '0.8': -0.9006400108337402},
#  {'0.0': -0.043680000305175784,
#   '0.1': 0.9595199584960937,
#   '0.2': 0.9766400337219239,
#   '0.4': 0.9774399757385254,
#   '0.6': 0.9572799682617188,
#   '0.8': 0.9292799949645996})

# %%
N_star = [1, 1000, 5000, 10000]
h.Q17(N_star)
# Out:
# ({'1': -0.49520001411437986,
#   '1000': -0.36464002132415774,
#   '5000': -0.3334400177001953,
#   '10000': -0.35984001159667967},
#  {'1': 0.9524800300598144,
#   '1000': 0.9671999931335449,
#   '5000': 0.9736000061035156,
#   '10000': 0.9769599914550782})

# %% [markdown]
# Question 19:
# train the best player

# %%
h.Q19_train()

# %% [markdown]
# Plot its performance

# %%
policy_net = h.DQN().to(device)
target_net = h.DQN().to(device)
question = 'q3-19_train'
PATH = './Data/model' + question + '.pth'
target_net.load_state_dict(torch.load(PATH, map_location= torch.device(device)))
policy_net.load_state_dict(torch.load(PATH, map_location= torch.device(device)))
memory = h.ReplayMemory(buffer_size)
playerDQN = h.DQN_Player(0, policy_net, target_net, memory)
h.Q19(playerDQN)
