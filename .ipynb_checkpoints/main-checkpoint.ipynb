# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import helpers as h
from nim_env import NimEnv, OptimalPlayer, QL_Player
# %matplotlib inline
plt.rc('text', usetex = True)

# %% [markdown]
# # Q-Learning agent

# %% [markdown]
# ### Q1)

# %%
rewardsQ1_5_samples = h.Q1()
rewardsQ1_1_sample = h.Q1(nb_samples = 1)

# %% [markdown]
# ### Q2)

# %%
N_star = [1, 1000, 5000, 10000]
dict_rewardsQ2_5_samples = h.Q2(N_star = N_star)
dict_rewardsQ2_1_sample = h.Q2(N_star = N_star, nb_samples = 1)

# %% [markdown]
# With a big $n_*$, the decrease of epsilon is very slow, and stays very close to $\epsilon_\text{max} = 0.8$. This prevents the algorithm from reaching a good performance after $20000$ games, compared to having a fixed epsilon. Surprisingly, with almost no exploration, the algorithm yields a similar performance as with 1000 games of exploration. The following cell allows to zoom more in detail to see the differences between $n_* = 1$ and $n_* = 1000$

# %%
N_star = [1, 1000]
dict_rewardsQ2_small = h.Q2(nb_games = 8000, N_star = N_star, question = "q2-2_small")

# %% [markdown]
# We can see that the results are very close.

# %% [markdown]
# ### Q3)

# %%
N_star = [1, 1000, 5000, 10000]
dictMoptQ3_5_samples, dictMrandQ3_5_samples = h.Q3(N_star = N_star)
dictMoptQ3_1_sample, dictMrandQ3_5_samples = h.Q3(N_star = N_star, nb_samples = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_675/302566727.py in <module>
#       1 N_star = [1, 1000, 5000, 10000]
# ----> 2 dictMoptQ3_5_samples, dictMrandQ3_5_samples = h.Q3(N_star = N_star)
#       3 dictMoptQ3_1_sample, dictMrandQ3_5_samples = h.Q3(N_star = N_star, nb_samples = 1)
#
# ~/ANN_NIM/helpers.py in Q3(N_star, nb_games, eps_min, eps_max, alpha, gamma, step, seed, question, nb_samples, save)
#     324                                 playerRand.player = 1
#     325                                 playerQL.player = 0
# --> 326                             mrand += QL_one_game(playerQL, playerRand, eps = playerQL.epsilon, eps_opt = playerRand.epsilon,
#     327                                                  alpha = alpha, gamma = gamma, env = new_env, update = False)
#     328                             new_env.reset()
#
# ~/ANN_NIM/helpers.py in QL_one_game(playerQL, playerOpt, eps, eps_opt, alpha, gamma, env, update)
#      34     while not env.end:
#      35         if env.current_player == playerOpt.player:
# ---> 36             move = playerOpt.act(heaps)
#      37             heaps, end, winner = env.step(move)
#      38             if i > 0 and update == True:
#
# ~/ANN_NIM/nim_env.py in act(self, heaps, **kwargs)
#     210         """
#     211         if random.random() < self.epsilon:
# --> 212             return self.randomMove(heaps)
#     213
#     214         else:
#
# ~/ANN_NIM/nim_env.py in randomMove(self, heaps)
#     157         """
#     158         # the indexes of the heaps available are given by
# --> 159         heaps_avail = [i for i in range(len(heaps)) if heaps[i] > 0]
#     160         chosen_heap = random.choice(heaps_avail)
#     161         n_obj = random.choice(range(1, heaps[chosen_heap] + 1))
#
# KeyboardInterrupt:

# %% [markdown]
# ### Q4)

# %% [markdown]
# ### Q7)

# %% [markdown]
# ### Q8)

# %% [markdown]
# ### Q10)
